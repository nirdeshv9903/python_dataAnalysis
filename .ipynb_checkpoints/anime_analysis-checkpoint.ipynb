# %% [markdown]
# # Let's import the library first !!!!!!!!!!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Some basic formating for the graph's

# %%
# The dataset was up to 2023.
import matplotlib
matplotlib.use("nbAgg") # interactive plot in jupyter notebook

# %%
# Change the default format for the vector formate
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
# Out:
# C:\Users\nirde\AppData\Local\Temp\ipykernel_18032\3850821838.py:3: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
# dataset importing 
anime_data = pd.read_csv('anime-dataset-2023.csv')
anime_data
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# ...

# %% [markdown]
# ## Data cleaning and Mata Data

# %%
# let chech the data type
type(anime_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# shape of data will be
anime_data.shape
# Out:
# (24905, 24)

# %%
# let's check who many columns is has
anime_data.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %%
# Number of index's be have
anime_data.index
# Out:
# RangeIndex(start=0, stop=24905, step=1)

# %%
# Size of the data
anime_data.size
# Out:
# 597720

# %%
# Top five row in dataset
anime_data.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
# least five rows
anime_data.tail()
# Out:
#        anime_id                      Name     English name Other name  \
# 24900     55731               Wu Nao Monu          UNKNOWN       无脑魔女
# 24901     55732       Bu Xing Si: Yuan Qi      Blader Soul     捕星司·源起
# 24902     55733               Di Yi Xulie  The First Order       第一序列
# 24903     55734  Bokura no Saishuu Sensou          UNKNOWN    僕らの最終戦争
# 24904     55735            Shijuuku Nichi          UNKNOWN       四十九日
#
#          Score                              Genres  \
# 24900  UNKNOWN      Comedy, Fantasy, Slice of Life
# 24901  UNKNOWN          Action, Adventure, Fantasy
# 24902  UNKNOWN  Action, Adventure, Fantasy, Sci-Fi
# 24903  UNKNOWN                             UNKNOWN
# 24904  UNKNOWN                             UNKNOWN
#
#                                                 Synopsis   Type Episodes  \
# 24900           No description available for this anime.    ONA     15.0
# 24901           No description available for this anime.    ONA     18.0
# ...

# %%
# Some information about the data is
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
# ...

# %%
# Some statistics about the data
anime_data.describe()
# Out:
#            anime_id    Popularity      Favorites       Members
# count  24905.000000  24905.000000   24905.000000  2.490500e+04
# mean   29776.709014  12265.388356     432.595222  3.710496e+04
# std    17976.076290   7187.428393    4353.181647  1.568252e+05
# min        1.000000      0.000000       0.000000  0.000000e+00
# 25%    10507.000000   6040.000000       0.000000  2.090000e+02
# 50%    34628.000000  12265.000000       1.000000  1.056000e+03
# 75%    45240.000000  18491.000000      18.000000  9.326000e+03
# max    55735.000000  24723.000000  217606.000000  3.744541e+06

# %%
# let's find the Null value in our data set
anime_data.isnull()
# Out:
#        anime_id   Name  English name  Other name  Score  Genres  Synopsis  \
# 0         False  False         False       False  False   False     False
# 1         False  False         False       False  False   False     False
# 2         False  False         False       False  False   False     False
# 3         False  False         False       False  False   False     False
# 4         False  False         False       False  False   False     False
# ...         ...    ...           ...         ...    ...     ...       ...
# 24900     False  False         False       False  False   False     False
# 24901     False  False         False       False  False   False     False
# 24902     False  False         False       False  False   False     False
# 24903     False  False         False       False  False   False     False
# 24904     False  False         False       False  False   False     False
#
#         Type  Episodes  Aired  ...  Studios  Source  Duration  Rating   Rank  \
# ...

# %%
anime_data.isnull().sum()
# Out:
# anime_id        0
# Name            0
# English name    0
# Other name      0
# Score           0
# Genres          0
# Synopsis        0
# Type            0
# Episodes        0
# Aired           0
# Premiered       0
# Status          0
# Producers       0
# Licensors       0
# Studios         0
# Source          0
# Duration        0
# Rating          0
# Rank            0
# Popularity      0
# Favorites       0
# Scored By       0
# Members         0
# Image URL       0
# dtype: int64

# %%
#Removing Duplicates 
anime_data.drop_duplicates(inplace=True)

# %% [markdown]
# ## Analysis of anime and Manga

# %%
# let's extrat the some of the col in dataset and print only top 50 row of them
anime_data.iloc[0:-1,[1,2,5,7,18,8.14,15]].head(50)
# Out:
#                                                  Name  \
# 0                                        Cowboy Bebop
# 1                     Cowboy Bebop: Tengoku no Tobira
# 2                                              Trigun
# 3                                  Witch Hunter Robin
# 4                                      Bouken Ou Beet
# 5                                        Eyeshield 21
# 6                                Hachimitsu to Clover
# 7                          Hungry Heart: Wild Striker
# 8                              Initial D Fourth Stage
# 9                                             Monster
# 10                                             Naruto
# 11                                          One Piece
# 12                                Tennis no Ouji-sama
# 13                                   Ring ni Kakero 1
# 14                                      School Rumble
# 15                                          Sunabouzu
# ...

# %%
# change the name of clo "Other name" to "Orignal name"
nd = anime_data.rename(columns={"Other name": "Orignal Name"})

# %%
nd.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Orignal Name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %% [markdown]
# ### Name of the Anime in Different language.

# %%
# let's know baout the animes names in differrnt language in details with it Members and discription
nd[["Name", "English name", "Orignal Name", "Synopsis", "Members"]].head(30)
# Out:
#                                                  Name  \
# 0                                        Cowboy Bebop
# 1                     Cowboy Bebop: Tengoku no Tobira
# 2                                              Trigun
# 3                                  Witch Hunter Robin
# 4                                      Bouken Ou Beet
# 5                                        Eyeshield 21
# 6                                Hachimitsu to Clover
# 7                          Hungry Heart: Wild Striker
# 8                              Initial D Fourth Stage
# 9                                             Monster
# 10                                             Naruto
# 11                                          One Piece
# 12                                Tennis no Ouji-sama
# 13                                   Ring ni Kakero 1
# 14                                      School Rumble
# 15                                          Sunabouzu
# ...

# %% [markdown]
# ### Category of Anime Repersent in chart

# %%
category = anime_data.Rating.unique()
category
# Out:
# array(['R - 17+ (violence & profanity)', 'PG-13 - Teens 13 or older',
#        'PG - Children', 'R+ - Mild Nudity', 'G - All Ages', 'Rx - Hentai',
#        'UNKNOWN'], dtype=object)

# %%
pd.DataFrame(category)
# Out:
#                                 0
# 0  R - 17+ (violence & profanity)
# 1       PG-13 - Teens 13 or older
# 2                   PG - Children
# 3                R+ - Mild Nudity
# 4                    G - All Ages
# 5                     Rx - Hentai
# 6                         UNKNOWN

# %%
# this graph is show only 20 index of the anime because data was too large
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(211) 
ax.set_title("Category Chart of Anime", fontweight="bold")
ax.set_xlabel("Anime Shows", color="red")
ax.set_ylabel("Category", color="red")
ax = plt.bar(nd["Name"][:20], nd["Rating"][:20], color = "red")
ax = plt.grid(linewidth = 0.2, color = "black", alpha = 0.3)
ax = plt.xticks(rotation=45, ha='right', fontsize=7)
ax = plt.yticks(rotation=0, ha='right', fontsize=7)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Top Ranking of anime.

# %%
top_anime = anime_data.sort_values(by="Rank", ascending=True).head(10)  # Top 10 ranked anime
ta = top_anime.fillna(0)
ta # ta[["Name", "Rank"]]
# Out:
#        anime_id                               Name  \
# 24904     55735                     Shijuuku Nichi
# 24498     55227                       Night Flower
# 24494     55218                    The Little Name
# 24468     55178               Ridin' (IMLAY Remix)
# 24464     55174               Bad Boy (Slom Remix)
# 24463     55173              Bad Boy (nomad Remix)
# 24462     55172  맛 (Hot Sauce) (MINIMONSTER Remix)
# 24461     55171                Bambi (h4rdy Remix)
# 24460     55170         Don't Call Me (ESAI Remix)
# 24458     55167                            Animals
#
#                         English name Other name  Score     Genres  \
# 24904                        UNKNOWN       四十九日    0.0    UNKNOWN
# 24498                   Night Flower         야화    0.0  Boys Love
# 24494                The Little Name       어린이름    0.0    UNKNOWN
# 24468           Ridin' (IMLAY Remix)    UNKNOWN    0.0    UNKNOWN
# 24464           Bad Boy (Slom Remix)    UNKNOWN    0.0    UNKNOWN
# ...

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot()
plt.barh(anime_data["Name"][:10], anime_data["Rank"][:10], color = "#324a5f")
plt.title('Ranking of Anime', fontsize=14, fontweight='bold')
plt.yticks(fontsize=6, weight="bold")
plt.xticks(fontsize=5, weight="bold")
ax.set_xlabel("Ranking", weight='bold', c="#324a5f")
ax.set_ylabel("Name of Anime", weight='bold', c="#324a5f")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(211)
ax.set_title("Members in anime funclub", fontweight="bold")
ax.set_xlabel("Anime Name's", color="#5a189a")
ax.set_ylabel("Members", color="#5a189a")
ax = plt.bar(nd["Name"][:20], nd["Members"][:20], color = "#5a189a")
ax = plt.grid(linewidth = 0.2, color = "black", alpha = 0.3)
ax = plt.xticks(rotation=45, ha='right', fontsize=7)
ax = plt.yticks(rotation=0, ha='right', fontsize=7)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Sourcses for anime where you watch
nd[["Name", "Image URL"]].head(20)
# Out:
#                                Name  \
# 0                      Cowboy Bebop
# 1   Cowboy Bebop: Tengoku no Tobira
# 2                            Trigun
# 3                Witch Hunter Robin
# 4                    Bouken Ou Beet
# 5                      Eyeshield 21
# 6              Hachimitsu to Clover
# 7        Hungry Heart: Wild Striker
# 8            Initial D Fourth Stage
# 9                           Monster
# 10                           Naruto
# 11                        One Piece
# 12              Tennis no Ouji-sama
# 13                 Ring ni Kakero 1
# 14                    School Rumble
# 15                        Sunabouzu
# 16                       Texhnolyze
# 17                    Trinity Blood
# 18                 Yakitate!! Japan
# 19                           Zipang
#
#                                             Image URL
# 0   https://cdn.myanimelist.net/images/anime/4/196...
# 1   https://cdn.myanimelist.net/images/anime/1439/...
# ...

# %% [markdown]
# ### Anime TV Series and movies in Dataset

# %%
# Anime TV Series and movies in Dataset
# Count the number of Anime Series (TV) and Movies
anime_type_counts = anime_data["Type"].value_counts()

# Extract TV series and Movie counts
tv_count = anime_type_counts.get("TV", 0)
movie_count = anime_type_counts.get("Movie", 0)

# Display the results
tv_count, movie_count
# Out:
# (7597, 4381)

# %%
anime_tv = anime_data[anime_data["Type"] == "TV"]
# anime_tv.head()
anime_tv[["Name", "Type"]]
# Out:
#                                                     Name Type
# 0                                           Cowboy Bebop   TV
# 2                                                 Trigun   TV
# 3                                     Witch Hunter Robin   TV
# 4                                         Bouken Ou Beet   TV
# 5                                           Eyeshield 21   TV
# ...                                                  ...  ...
# 24842                    Alssongdalssong Catch! Tiniping   TV
# 24867             Boku no Kokoro no Yabai Yatsu Season 2   TV
# 24875                Kimetsu no Yaiba: Hashira Geiko-hen   TV
# 24876             Kimetsu no Yaiba: Purātorēninguāku-hen   TV
# 24886  Dekisokonai to Yobareta Motoeiyuu wa Jikka kar...   TV
#
# [7597 rows x 2 columns]

# %%
anime_movie = anime_data[anime_data["Type"] == "Movie"]
anime_movie[["Name", "Type"]]
# Out:
#                                                     Name   Type
# 1                        Cowboy Bebop: Tengoku no Tobira  Movie
# 21              Neon Genesis Evangelion: Death & Rebirth  Movie
# 22        Neon Genesis Evangelion: The End of Evangelion  Movie
# 24                                      Koukaku Kidoutai  Movie
# 27     Rurouni Kenshin: Meiji Kenkaku Romantan - Ishi...  Movie
# ...                                                  ...    ...
# 24817                                Haruzora to Akizora  Movie
# 24819                                      Dynamic Venus  Movie
# 24827                            Wasure Hoshi no Volicia  Movie
# 24882                               Boku to Roboko Movie  Movie
# 24884                                       Retro Future  Movie
#
# [4381 rows x 2 columns]

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(211)
ax.set_xlabel("Anime Name", c="#22223b")
ax.set_ylabel("Anime Type", c="#22223b")
plt.title("Type of the Anime", fontweight="bold")
plt.scatter(nd["Name"][20:50], nd["Type"][20:50], s=10, c="#22223b")
ax = plt.xticks(rotation=45, ha='right', fontsize=5)
ax = plt.yticks(rotation=0, ha='right', fontsize=6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Convert necessary columns to numeric, handling errors where applicable
anime_data["Score"] = pd.to_numeric(anime_data["Score"], errors='coerce')
anime_data["Episodes"] = pd.to_numeric(anime_data["Episodes"], errors='coerce')
anime_data["Rank"] = pd.to_numeric(anime_data["Rank"], errors='coerce')
anime_data["Scored By"] = pd.to_numeric(anime_data["Scored By"], errors='coerce')

# Extracting the first year from the "Aired" column using regex
anime_data["Year"] = anime_data["Aired"].str.extract(r'(\d{4})').astype(float)

# Checking the cleaned dataset
anime_data[["Name", "Score", "Episodes", "Rank", "Scored By", "Year"]].head(10)
# Out:
#                               Name  Score  Episodes    Rank  Scored By    Year
# 0                     Cowboy Bebop   8.75      26.0    41.0   914193.0  1998.0
# 1  Cowboy Bebop: Tengoku no Tobira   8.38       1.0   189.0   206248.0  2001.0
# 2                           Trigun   8.22      26.0   328.0   356739.0  1998.0
# 3               Witch Hunter Robin   7.25      26.0  2764.0    42829.0  2002.0
# 4                   Bouken Ou Beet   6.94      52.0  4240.0     6413.0  2004.0
# 5                     Eyeshield 21   7.92     145.0   688.0    86524.0  2005.0
# 6             Hachimitsu to Clover   8.00      24.0   589.0    81747.0  2005.0
# 7       Hungry Heart: Wild Striker   7.55      52.0  1551.0    12960.0  2002.0
# 8           Initial D Fourth Stage   8.16      24.0   393.0    97878.0  2004.0
# 9                          Monster   8.87      74.0    26.0   368569.0  2004.0

# %%
# Grouping by year to find average popularity over time
popularity_trend = anime_data.groupby("Year")["Popularity"].mean().dropna()

# Plot the popularity trend over time
plt.figure(figsize=(8, 4))
plt.plot(popularity_trend.index, popularity_trend.values, marker='o', linestyle='-')
plt.xlabel("Year")
plt.ylabel("Average Popularity Rank (Lower is Better)")
plt.title("Average Anime Popularity Rank Over Time", weight="bold")
plt.gca().invert_yaxis()  # Since lower popularity rank is better, invert the y-axis
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Finding the most popular anime for each year based on the lowest rank
most_popular = anime_data.loc[anime_data.groupby("Year")["Rank"].idxmin(),["Year", "Name", "Rank", "Score", "Popularity"]]
# Display the top results
most_popular.sort_values("Year", ascending=True).head(20)
# Out:
#          Year                                  Name     Rank  Score  \
# 8836   1917.0  Dekobou Shingachou: Meian no Shippai   9816.0   5.77
# 8674   1918.0                              Kobutori  10475.0   5.59
# 5018   1924.0                         Usagi to Kame  11647.0   5.17
# 9574   1925.0                           Ubasuteyama  11095.0   5.40
# 5020   1926.0        Saiyuuki: Son Gokuu Monogatari  11286.0   5.33
# 12952  1927.0               Saru Kani Gassen (1927)  11633.0   5.18
# 5022   1928.0               Doubutsu Olympic Taikai  11075.0   5.40
# 4337   1929.0                       Kobutori (1929)   9490.0   5.85
# 12671  1930.0                                  Roba  11136.0   5.38
# 3616   1931.0                            Kuro Nyago  11280.0   5.33
# 12967  1932.0                           Ahiru no Ko   9988.0   5.72
# 4967   1933.0         Chikara to Onna no Yo no Naka  10498.0   5.59
# 7209   1934.0            Tsuki no Miya no Oujo-sama  11485.0   5.25
# ...

# %%
# Filtering for anime from the year 2000 onwards
recent_popular_anime = most_popular[most_popular["Year"] >= 2000]
new_re = recent_popular_anime.fillna(0)
# Display top results from 2000 onwards
new_re.sort_values("Year", ascending=True).head(30)
# Out:
#          Year                                               Name   Rank  \
# 239    2000.0                                     Hajime no Ippo   40.0
# 176    2001.0                      Sen to Chihiro no Kamikakushi   36.0
# 24329  2002.0  Chibi Maruko-chan Special: Maruko, Fooku Konsa...    0.0
# 456    2003.0                  Kino no Tabi: The Beautiful World  246.0
# 24745  2004.0                                           The Anus    0.0
# 21479  2005.0                           Fate/stay night Specials    0.0
# 833    2006.0                                            Gintama   16.0
# 1822   2007.0                         Tengen Toppa Gurren Lagann   71.0
# 3527   2008.0                               Clannad: After Story   19.0
# 24177  2009.0                                     Meguriau Sekai    0.0
# 24795  2010.0  Wagaya no Liliana-san & Tonari no Ie no Anette...    0.0
# 24622  2011.0                                             BadBye    0.0
# ...

# %%
# Grouping by studios to find the most frequently occurring ones
studio_counts = anime_data["Studios"].str.split(", ").explode().value_counts().head(10)

# Finding the highest-rated studios based on average score
top_scoring_studios = anime_data.groupby("Studios")["Score"].mean().sort_values(ascending=False).head(10)

# Plot the most frequently appearing studios
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(211)
studio_counts.plot(kind="bar", color="#ff5400")
plt.xlabel("Studios", c="#ff5400")
plt.ylabel("Number of Anime Produced", c="#ff5400")
plt.title("Top 10 Most Prolific Anime Studios", fontweight="bold", c="#ff5400")
plt.xticks(rotation=60, ha='right', fontsize=8)
plt.show()

# Plot the highest-rated studios
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(211)
top_scoring_studios.plot(kind="bar", color="#40916c")
plt.xlabel("Studios", c="#40916c")
plt.ylabel("Average Score", c="#40916c")
plt.title("Top 10 Highest Rated Anime Studios (Avg Score)", fontweight="bold", c="#40916c")
plt.xticks(rotation=60, ha='right', fontsize=8)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %%
from collections import Counter

# Splitting and counting genres
genre_counts = Counter()
anime_data.dropna(subset=["Genres"], inplace=True)  # Dropping rows with missing genres

for genre_list in anime_data["Genres"]:
    genres = [g.strip() for g in genre_list.split(",")]
    genre_counts.update(genres)

# Convert to DataFrame for visualization
genre_df = pd.DataFrame(genre_counts.items(), columns=["Genre", "Count"]).sort_values(by="Count", ascending=False)

# Plot top genres
plt.figure(figsize=(10, 6))
plt.barh(genre_df["Genre"].head(10), genre_df["Count"].head(10), color="#da627d")
plt.xlabel("Number of Anime",  c="#da627d")
plt.ylabel("Genre",  c="#da627d")
plt.title("Top 10 Most Common Anime Genres", weight="bold", c="#da627d")
plt.gca().invert_yaxis()  # Flip for better visualization
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Anime Referance

# %%
# Anime Based on this filled 
anime_data.Source.unique()
# Out:
# array(['Original', 'Manga', 'Light novel', 'Game', 'Visual novel',
#        '4-koma manga', 'Novel', 'Other', 'Unknown', 'Picture book',
#        'Web manga', 'Music', 'Radio', 'Book', 'Mixed media', 'Card game',
#        'Web novel'], dtype=object)

# %%
pd.DataFrame(anime_data.Source.unique(), columns=["Referance of anime"]) # In DataFrame
# Out:
#    Referance of anime
# 0            Original
# 1               Manga
# 2         Light novel
# 3                Game
# 4        Visual novel
# 5        4-koma manga
# 6               Novel
# 7               Other
# 8             Unknown
# 9        Picture book
# 10          Web manga
# 11              Music
# 12              Radio
# 13               Book
# 14        Mixed media
# 15          Card game
# 16          Web novel

# %% [markdown]
# ### Anime Based on the Manga

# %%
# Filter anime based on manga source
manga_anime = anime_data[anime_data["Source"].str.lower() == "manga"]
# manga_anime.head()
manga_anime[["Name", "Source"]]
# Out:
#                                          Name Source
# 2                                      Trigun  Manga
# 4                              Bouken Ou Beet  Manga
# 5                                Eyeshield 21  Manga
# 6                        Hachimitsu to Clover  Manga
# 7                  Hungry Heart: Wild Striker  Manga
# ...                                       ...    ...
# 24835           Tonikaku Kawaii: Joshikou-hen  Manga
# 24867  Boku no Kokoro no Yabai Yatsu Season 2  Manga
# 24875     Kimetsu no Yaiba: Hashira Geiko-hen  Manga
# 24882                    Boku to Roboko Movie  Manga
# 24893                    Beauty and the Brawn  Manga
#
# [4687 rows x 2 columns]

# %%
source_counts = anime_data["Source"].value_counts()

# %%
fig = plt.figure(figsize=(8, 4))
fig.add_subplot(211)
source_counts.plot(kind="bar", color="#5c6b73", edgecolor="black")

# Labels and title
plt.xlabel("Source Type", c="#5c6b73")
plt.ylabel("Number of Anime", c="#5c6b73")
plt.title("Distribution of Anime by Source", fontweight="bold")
plt.xticks(rotation=45)  # Rotate labels for better readability

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
